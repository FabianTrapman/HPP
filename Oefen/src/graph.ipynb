# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 4, 8, 16, 32, 64, 128, 256]
y = [387.89, 177.82, 101.49, 62.72, 61.13, 60.72, 65.16, 78.11, 94.60]

# Create a plot
plt.plot(x, y, marker='o')

# Add title and labels
plt.title('Circuit Satisfiability MPI')
plt.xlabel('Hoeveelheid Cores')
plt.ylabel('Tijd in seconden')

# Show the plot
plt.show()
